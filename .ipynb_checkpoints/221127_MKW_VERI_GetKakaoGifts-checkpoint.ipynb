# %%
import pandas as pd
import os

# %%
file_list = [x for x in os.listdir(os.getcwd()) if '.csv' in x]
file_list
# Out:
# ['KAKAO_luxury.csv',
#  'KAKAO_touched.csv',
#  'KAKAO_baby.csv',
#  'KAKAO_funny.csv',
#  'KAKAO_samll_gift.csv',
#  'KAKAO_small_luxury.csv',
#  'KAKAO_birthday.csv',
#  'KAKAO_health.csv']

# %%
for file in file_list:
    df = pd.read_csv(f'./{file}', index_col = 0)
    display(df.head())
    print(df.shape)
# Out:
#                                                 name       price    type
# 0                                  티파니 T 스마일 펜던트(스몰)  1,450,000원  luxury
# 1  [친구맺고 3%적립] [본사정품/쇼핑백증정] Dazzling Swan 핑크스완 네크...    155,000원  luxury
# 2                       리턴 투 티파니 티파니 블루 더블 하트 태그 펜던트    385,000원  luxury
# 3  [친구맺고 3%적립] [본사정품/쇼핑백증정] Ginger 로즈골드 화이트 뱅글 (5...    155,000원  luxury
# 4                 리턴 투 티파니 티파니 블루 더블 하트 태그 다이아몬드 펜던트    580,000원  luxury
# (237, 3)
#                                name    price     type
# 0          리틀퍼피클럽 핫팩&파우치 세트_라이언/어피치  29,000원  touched
# 1               리틀퍼피클럽 양털부츠_라이언/어피치  25,000원  touched
# 2                   꿀잠친구_고슴도치 리틀라이언  42,000원  touched
# 3  "고흥 유자를 선물합니다" 자임 꿀유자차 580g x 2병  13,900원  touched
# 4        오설록 오~땡큐 티박스 6종 선물세트(총30입)  22,000원  touched
# (196, 3)
#                                                 name    price  type
# 0                       키즈 베이비 귀달이캡 아동 모자 NK8BCF502U  49,900원  baby
# ...

# %%
df['name'].iloc[2]
# Out:
# '"🎁마음의 선물🎁" 힘내라 홍삼정 For You 10ml x 30포 +리뷰이벤트 (리뉴얼ver)'
