# %%
import pandas as pd
import os

# %%
file_list = [x for x in os.listdir(os.getcwd()) if '.csv' in x]
file_list
# Out:
# ['KAKAO_luxury.csv',
#  'KAKAO_touched.csv',
#  'KAKAO_baby.csv',
#  'KAKAO_funny.csv',
#  'KAKAO_samll_gift.csv',
#  'KAKAO_small_luxury.csv',
#  'KAKAO_birthday.csv',
#  'KAKAO_health.csv']

# %%
file_list = ['KAKAO_baby.csv']

# %%
for file in file_list:
    df = pd.read_csv(f'./{file}', index_col = 0)
    display(df.head())
    print(df.shape)
# Out:
#                                                 name    price  type   종류  \
# 0                       키즈 베이비 귀달이캡 아동 모자 NK8BCF502U  49,900원  baby  털모자
# 1  "발이 따뜻한 털신발" 쿠로미 방한실내화 [키리] 가벼운 털실내화 180~250 m...  14,900원  baby  NaN
# 2                    [세트] 타요 롱 캐리어카 + 꼬마버스 친구들 세트 6종  34,900원  baby  NaN
# 3                             별의 여신 시크릿 쥬쥬 나만의 매직캐리어  37,900원  baby  NaN
# 4                          22FW 보아 양면 니트 머플러 (3종 택1)  37,050원  baby  NaN
#
#      소재                 치수           제조사  제조국 취급시 주의사항     품질보증기준  ...  \
# 0  아크릴면  너비 21cm x 깊이 26cm  롱쇼어 / 행복한바오밥   중국    세탁 불가  상품상세설명 참조  ...
# 1   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 2   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 3   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 4   NaN                NaN           NaN  NaN      NaN        NaN  ...
#
#        소비자 상담 관련 전화번호 소비자 안전을 위한 주의사항 수입품의 경우 생산자, 수입자 및 제조국  \
# 0  루솔 고객만족실 1644-2571       상품상세설명 참조              상품상세설명 참조
# 1                 NaN             NaN                    NaN
# 2                 NaN             NaN                    NaN
# 3                 NaN             NaN                    NaN
# 4                 NaN             NaN                    NaN
#
#                            제조연월일(포장일 또는 생산연도), 유통기한      영양성분     제품구성  \
# 0  2019.01.03 이후 생산되어 수시입고 되는 제품으로 자세한 내용은 루솔 고객센...  상세페이지참고  상세페이지참조
# 1                                                NaN      NaN      NaN
# 2                                                NaN      NaN      NaN
# 3                                                NaN      NaN      NaN
# 4                                                NaN      NaN      NaN
#
#   법에 의한 인증, 허가 등을 받았음을 확인할 수 있는 경우 그에 대한 사항 A/S 책임자와 전화번호 또는 소비자상담 관련 전화번호  \
# 0                                 상품상세설명 참조                      상품상세설명 참조
# 1                                       NaN                            NaN
# 2                                       NaN                            NaN
# 3                                       NaN                            NaN
# 4                                       NaN                            NaN
#
#          구성품 수입식품안전관리특별법에 따른 수입신고
# 0  상품상세설명 참조            상품상세설명 참조
# 1        NaN                  NaN
# 2        NaN                  NaN
# 3        NaN                  NaN
# 4        NaN                  NaN
#
# [5 rows x 45 columns]
# (97, 45)

# %%
df
# Out:
#                                                  name    price  type   종류  \
# 0                        키즈 베이비 귀달이캡 아동 모자 NK8BCF502U  49,900원  baby  털모자
# 1   "발이 따뜻한 털신발" 쿠로미 방한실내화 [키리] 가벼운 털실내화 180~250 m...  14,900원  baby  NaN
# 2                     [세트] 타요 롱 캐리어카 + 꼬마버스 친구들 세트 6종  34,900원  baby  NaN
# 3                              별의 여신 시크릿 쥬쥬 나만의 매직캐리어  37,900원  baby  NaN
# 4                           22FW 보아 양면 니트 머플러 (3종 택1)  37,050원  baby  NaN
# ..                                                ...      ...   ...  ...
# 92   [조카선물] [생일선물] 메이크잇리얼 겨울왕국2 DIY 팔찌만들기 비즈만들기 디즈니팔찌  20,500원  baby  NaN
# 93                        [스틱오by맥포머스] 핑크퐁 아기상어 프렌즈 세트  55,200원  baby  NaN
# 94   "포켓몬 키링 20P" [단체선물] 포켓몬 키링 20P 세트 포켓몬스터 열쇠고리 장난감  37,900원  baby  NaN
# 95                             5648-실바니안 블라인드백_아기 디저트   9,500원  baby  NaN
# 96        "크리스마스 선물" [조카선물] 보드게임인 척 수학 공부하게 되는 셈셈 시리즈  29,700원  baby  NaN
#
#       소재                 치수           제조사  제조국 취급시 주의사항     품질보증기준  ...  \
# 0   아크릴면  너비 21cm x 깊이 26cm  롱쇼어 / 행복한바오밥   중국    세탁 불가  상품상세설명 참조  ...
# 1    NaN                NaN           NaN  NaN      NaN        NaN  ...
# 2    NaN                NaN           NaN  NaN      NaN        NaN  ...
# 3    NaN                NaN           NaN  NaN      NaN        NaN  ...
# 4    NaN                NaN           NaN  NaN      NaN        NaN  ...
# ..   ...                ...           ...  ...      ...        ...  ...
# 92   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 93   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 94   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 95   NaN                NaN           NaN  NaN      NaN        NaN  ...
# 96   NaN                NaN           NaN  NaN      NaN        NaN  ...
#
#         소비자 상담 관련 전화번호 소비자 안전을 위한 주의사항 수입품의 경우 생산자, 수입자 및 제조국  \
# 0   루솔 고객만족실 1644-2571       상품상세설명 참조              상품상세설명 참조
# 1                  NaN             NaN                    NaN
# 2                  NaN             NaN                    NaN
# 3                  NaN             NaN                    NaN
# 4                  NaN             NaN                    NaN
# ..                 ...             ...                    ...
# 92                 NaN             NaN                    NaN
# 93                 NaN             NaN                    NaN
# 94                 NaN             NaN                    NaN
# 95                 NaN             NaN                    NaN
# 96                 NaN             NaN                    NaN
#
#                             제조연월일(포장일 또는 생산연도), 유통기한      영양성분     제품구성  \
# 0   2019.01.03 이후 생산되어 수시입고 되는 제품으로 자세한 내용은 루솔 고객센...  상세페이지참고  상세페이지참조
# 1                                                 NaN      NaN      NaN
# 2                                                 NaN      NaN      NaN
# 3                                                 NaN      NaN      NaN
# 4                                                 NaN      NaN      NaN
# ..                                                ...      ...      ...
# 92                                                NaN      NaN      NaN
# 93                                                NaN      NaN      NaN
# 94                                                NaN      NaN      NaN
# 95                                                NaN      NaN      NaN
# 96                                                NaN      NaN      NaN
#
#    법에 의한 인증, 허가 등을 받았음을 확인할 수 있는 경우 그에 대한 사항 A/S 책임자와 전화번호 또는 소비자상담 관련 전화번호  \
# 0                                  상품상세설명 참조                      상품상세설명 참조
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
# ..                                       ...                            ...
# 92                                       NaN                            NaN
# 93                                       NaN                            NaN
# 94                                       NaN                            NaN
# 95                                       NaN                            NaN
# 96                                       NaN                            NaN
#
#           구성품 수입식품안전관리특별법에 따른 수입신고
# 0   상품상세설명 참조            상품상세설명 참조
# 1         NaN                  NaN
# 2         NaN                  NaN
# 3         NaN                  NaN
# 4         NaN                  NaN
# ..        ...                  ...
# 92        NaN                  NaN
# 93        NaN                  NaN
# 94        NaN                  NaN
# 95        NaN                  NaN
# 96        NaN                  NaN
#
# [97 rows x 45 columns]
